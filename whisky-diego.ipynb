# %%
## importando a biblioteca pandas e pyplot
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
plt.style.use('ggplot')

# importando o arquivo csv
df = pd.read_csv('whisky.csv')
#### COMANDOS BÁSICOS
print(df) #mostra dataframe sumario
#print(df.head(3)) mostra 3 primeiros do dataframe
#print(df.tail(3)) mostra 3 ultimos do dataframe
#df.columns.tolist() # imprime as colunas em formato lista
#print(df['Distillery'])
#print(df.iloc[0:20]) # le o intervalo de linhas que quiser
#print(df.iloc[2,1]) # le uma celula especifica
#for index, row in df.iterrows(): # passa por todas as linhas retornando somente a coluna especifica
#    print(index, row['Distillery'])
df.loc[df['Body'] == 4] # traz somente os que tem nível 4 no paladar smoky
#df.describe() # raz um resumo com os quarters e tudo mais
#df.head(10)
#df.sort_values('Smoky', ascending=False) # ordena por coluna que quiser, neste caso duas colunas DESC
#df.sort_values(['Body', 'Smoky'], ascending=False) # ordena por coluna que quiser, neste caso duas colunas DESC

# CONFIRMANDO O NÚMERO DE4 AMOSTRAS E DE CADA TIPO DE WHISKY
#print (df['Distillery'].count())
#print (df['Distillery'].value_counts())
# Out:
# RowID    Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  \
# 0       1     Aberfeldy     2          2      2          0        0      2
# 1       2      Aberlour     3          3      1          0        0      4
# 2       3        AnCnoc     1          3      2          0        0      2
# 3       4        Ardbeg     4          1      4          4        0      0
# 4       5       Ardmore     2          2      2          0        0      1
# ..    ...           ...   ...        ...    ...        ...      ...    ...
# 81     82     Tobermory     1          1      1          0        0      1
# 82     83       Tomatin     2          3      2          0        0      2
# 83     84     Tomintoul     0          3      1          0        0      2
# 84     85       Tormore     2          2      1          0        0      1
# 85     86  Tullibardine     2          3      0          0        1      0
#
#     Spicy  Winey  Nutty  Malty  Fruity  Floral    Postcode  Latitude  \
# ...

# %%
# criando um scatter plot de atributos com o Matplotib 
plt.plot(df['Distillery'],df["Body"]+df["Sweetness"]+df["Smoky"]+df["Medicinal"]+df["Tobacco"]+df["Honey"]+df["Spicy"]+df["Winey"]+df["Nutty"]+df["Fruity"]+df["Floral"],marker='.',linestyle='none')
plt.show()

# %%
# usando FacetGrid do Seaborn para criar uma scatterplot colorida conforme o atributo species
sns.FacetGrid(df, hue="Distillery", size=6) \
   .map(plt.scatter, "Body", "Smoky") \
   .add_legend()

# %%
# %matplotlib inline
whisky = df[['RowID','Distillery', 'Body', 'Sweetness', 'Smoky', 'Medicinal',
       'Tobacco', 'Honey', 'Spicy', 'Winey', 'Nutty', 'Malty', 'Fruity',
       'Floral', 'Postcode', 'Latitude', 'Longitude']]
df[['Body', 'Sweetness', 'Smoky', 'Medicinal',
       'Tobacco', 'Honey', 'Spicy', 'Winey', 'Nutty', 'Malty', 'Fruity',
       'Floral']]
# Out:
#     Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  Winey  Nutty  \
# 0      2          2      2          0        0      2      1      2      2
# 1      3          3      1          0        0      4      3      2      2
# 2      1          3      2          0        0      2      0      0      2
# 3      4          1      4          4        0      0      2      0      1
# 4      2          2      2          0        0      1      1      1      2
# ..   ...        ...    ...        ...      ...    ...    ...    ...    ...
# 81     1          1      1          0        0      1      0      0      1
# 82     2          3      2          0        0      2      2      1      1
# 83     0          3      1          0        0      2      2      1      1
# 84     2          2      1          0        0      1      0      1      2
# 85     2          3      0          0        1      0      2      1      1
#
#     Malty  Fruity  Floral
# 0       2       2       2
# ...
